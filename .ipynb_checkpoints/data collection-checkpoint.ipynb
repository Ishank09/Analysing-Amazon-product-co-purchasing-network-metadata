# %%
# !pip3 install tqdm
# Out:
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (4.65.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
 # !pip install xeus-python
# Out:
# Collecting xeus-python
#   Downloading xeus_python-0.15.0-cp39-cp39-macosx_10_16_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 1.0 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: pygments<3,>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from xeus-python) (2.15.0)
# Collecting xeus-python-shell[ipython]<0.6,>=0.5
#   Downloading xeus_python_shell-0.5.0-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: debugpy<2,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (1.6.7)
# Requirement already satisfied: ipython<9,>=7.21 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (8.12.0)
# Requirement already satisfied: appnope in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.1.3)
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (3.0.38)
# Requirement already satisfied: stack-data in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.6.2)
# Requirement already satisfied: backcall in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.2.0)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (5.9.0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (4.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jedi>=0.16->ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pexpect>4.3->ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.7.0)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.2.6)
# Requirement already satisfied: pure-eval in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from stack-data->ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from stack-data->ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from stack-data->ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (1.2.0)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data->ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (1.16.0)
# Installing collected packages: xeus-python-shell, xeus-python
# Successfully installed xeus-python-0.15.0 xeus-python-shell-0.5.0
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import re
import json
from time import sleep
from tqdm import tqdm
def parse_text_to_json(text):
    import re
    # global block regex
    pattern = r'(Id): ([^\n]+)\n(ASIN): ([^\n]+)(?:\n  (title): ([^\n]+))?(?:\n  (group): ([^\n]+))?(?:\n  (salesrank): ([^\n]+))?(?:\n  (similar): ([^\n]+))?(?:\n  (categories):([\s\S]*?)(?=\n\n|\n  reviews))?(?:\n  (reviews):([\s\S]*?)(?=\n\n|\n  Id))?'

    matches = re.findall(pattern, text)
    resp = []
    groups = {}

    for match in tqdm(matches):
        groups = {}
        for i in range(len(match)):
            if i % 2 == 0:
                key = match[i]
            else:
                value = match[i]
                if key == 'Id':
                    value = int(value)
                elif key == 'salesrank':
                    value = int(value)
                elif key == 'similar':
                    value = value.split()[1:]
                elif key == 'categories':
                    value = [[x.strip() for x in t.split('|')] for t in value.strip().split('\n')[1:]]
                elif key == 'reviews':
                    reviews = {}
                    # review regex
                    review_pattern = r'\s*(total):\s+(\d+)\s+(downloaded):\s+(\d+)\s+(avg rating):\s+([\d+])\n?((?:\s{4}.*)*)'
                    review_matches = re.findall(review_pattern, value)
                    if review_matches:
                        for ri in range(len(review_matches[0])):
                            if ri==6:
                                rval = review_matches[0][ri]
                                revs = []
                                # customer review regex
                                cust_review_pattern = r'\s*(\d{4}-\d{1,2}-\d{1,2})\s+(cutomer):\s+(\w+)\s+(rating):\s+(\d+)\s+(votes):\s+(\d+)\s+(helpful):\s+(\d+)\s*'
                                cust_review_matches = re.findall(cust_review_pattern, rval)
                                if cust_review_matches:
                                    for cust_review_match in cust_review_matches:
                                        cus = {}
                                        for cri in range(len(cust_review_match)):
                                            if cri == 0:
                                                cus['date'] = cust_review_match[cri]
                                                continue
                                            if cri % 2 == 1:
                                                crkey = cust_review_match[cri]
                                            else:
                                                crvalue = cust_review_match[cri]
                                                if crkey == 'cutomer':
                                                    crvalue = crvalue
                                                elif crkey == 'rating':
                                                    crvalue = int(crvalue)
                                                elif crkey == 'votes':
                                                    crvalue = int(crvalue)
                                                elif crkey == 'helpful':
                                                    crvalue = int(crvalue)
                                                cus[crkey] = crvalue
                                        revs.append(cus)
                                
                                reviews['customer_reviews'] = revs
                                break
                            if ri % 2 == 0:
                                rkey = review_matches[0][ri]
                            else:
                                rvalue = review_matches[0][ri]
                                if rkey == 'total':
                                    rvalue = int(rvalue)
                                elif rkey == 'downloaded':
                                    rvalue = int(rvalue)
                                elif rkey == 'avg rating':
                                    rvalue = int(rvalue)
                                reviews[rkey] = rvalue
                   
                    value = reviews
                groups[key] = value
        resp.append(groups)

    with open("data/amazon-meta.txt", "w") as file:
        json.dump(resp, file)
    groups = {}

data = ""
with open('data/sample.txt', 'r') as file:
    data = file.read()
parse_text_to_json(data)
# Out:
# 100%|##########| 9/9 [00:00<00:00, 16607.45it/s]

# %%
import json
import re
from tqdm import tqdm
import os

files = ["amazon0302.txt", "amazon0312.txt", "amazon0505.txt", "amazon0601.txt"]
data = []
date_pattern = r"\b(?:January|February|March|April|May|June|July|August|September|October|November|December)\s+\d{1,2}\s+\d{4}\b"

for file in tqdm(files):
    with open(os.path.join("data",file), "r") as f:
        lines = f.readlines()
        match = re.search(date_pattern, lines[1].strip())

        if match:
            date = match.group(0)
        else:
            date = ''
        adjacency_matrix = []
        for line in tqdm(lines[4:]):
            parts = line.strip().split("\t")
            adjacency_matrix.append({"From": int(parts[0]), "To": int(parts[1])})
        with open(f"data/{date}.json", "w") as out_file:
            json.dump(adjacency_matrix, out_file)
# Out:
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#   0%|                                               | 0/1234877 [00:00<?, ?it/s]
#   3%|▉                              | 39270/1234877 [00:00<00:03, 392688.20it/s]
#   9%|██▋                           | 109305/1234877 [00:00<00:01, 573649.33it/s]
#  15%|████▍                         | 184106/1234877 [00:00<00:01, 653249.82it/s]
#  21%|██████▎                       | 261134/1234877 [00:00<00:01, 699436.61it/s]
#  27%|████████                      | 334181/1234877 [00:00<00:01, 710614.56it/s]
#  33%|██████████                    | 413167/1234877 [00:00<00:01, 737549.10it/s]
#  40%|███████████▉                  | 491333/1234877 [00:00<00:00, 751960.44it/s]
#  46%|█████████████▊                | 566530/1234877 [00:00<00:00, 746749.94it/s]
#  52%|███████████████▌              | 641213/1234877 [00:00<00:00, 735952.08it/s]
#  58%|█████████████████▎            | 714842/1234877 [00:01<00:00, 728887.62it/s]
#  64%|███████████████████▏          | 787761/1234877 [00:01<00:00, 721085.76it/s]
#  70%|█████████████████████         | 865375/1234877 [00:01<00:00, 737505.06it/s]
#  76%|██████████████████████▊       | 939176/1234877 [00:01<00:00, 664428.10it/s]
#  82%|███████████████████████▋     | 1011111/1234877 [00:01<00:00, 679680.31it/s]
#  88%|█████████████████████████▍   | 1082667/1234877 [00:01<00:00, 689864.11it/s]
#  93%|███████████████████████████  | 1152460/1234877 [00:01<00:00, 631289.58it/s]
# 100%|█████████████████████████████| 1234877/1234877 [00:01<00:00, 685861.83it/s]
